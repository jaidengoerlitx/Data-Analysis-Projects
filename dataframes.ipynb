# %% [markdown]
# <a href="https://colab.research.google.com/github/jaidengoerlitx/Data-Analysis-Projects/blob/main/dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import IPython.display
# %cd /content/drive/MyDrive/ColabNotebooks
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ColabNotebooks

# %%
# import pandas module 
import pandas as pd 
    
# making dataframe 
df1 = pd.read_csv("output_500000.csv") 
   
# output the dataframe
print(df1)

df1.head(1)
# Out:
#          En     id                                              atoms  \
# 0    7.3580  25020          ['Cl', 'N', 'C', 'C', 'H', 'H', 'H', 'H']
# 1   11.8509  25059  ['Br', 'Br', 'O', 'N', 'N', 'C', 'C', 'C', 'H'...
# 2    1.1785  25128  ['F', 'O', 'O', 'N', 'C', 'C', 'H', 'H', 'H', ...
# 3    4.8583  25188           ['O', 'O', 'C', 'C', 'C', 'H', 'H', 'H']
# 4    0.0000  25242                               ['F', 'F', 'N', 'H']
# ..      ...    ...                                                ...
# 90   6.6401  43581  ['O', 'O', 'O', 'O', 'N', 'C', 'C', 'H', 'H', ...
# 91   4.5991  43600  ['Br', 'S', 'N', 'N', 'C', 'C', 'C', 'H', 'H',...
# 92  -1.9294  44250  ['Cl', 'C', 'C', 'C', 'C', 'H', 'H', 'H', 'H',...
# 93   4.4494  45163  ['S', 'O', 'O', 'N', 'C', 'C', 'C', 'H', 'H', ...
# 94   0.0000  46209                                         ['F', 'O']
#
#                                        coulomb_matrix
# 0   [4.48794386e+02 6.75320922e+01 3.86237878e+01 ...
# ...

# %%
# making dataframe 
df2 = pd.read_csv("output_25000.csv") 
   
# output the dataframe
print(df2)

df2.head(1)
# Out:
#           En     id                                              atoms  \
# 0     0.3519     11         ['Cl', 'Cl', 'C', 'C', 'H', 'H', 'H', 'H']
# 1     1.3617     33               ['Cl', 'O', 'C', 'C', 'H', 'H', 'H']
# 2     0.3991     34     ['Cl', 'O', 'C', 'C', 'H', 'H', 'H', 'H', 'H']
# 3    10.7891     44  ['O', 'O', 'O', 'O', 'O', 'C', 'C', 'C', 'H', ...
# 4     2.1242    174  ['O', 'O', 'C', 'C', 'H', 'H', 'H', 'H', 'H', ...
# ..       ...    ...                                                ...
# 591   0.0000  24823                                    ['O', 'O', 'O']
# 592   0.0000  24841                                         ['I', 'H']
# 593  -0.1416  24845                     ['F', 'F', 'F', 'F', 'N', 'N']
# 594   0.0000  24855                                         ['I', 'I']
# 595   0.4044  24883    ['Cl', 'Cl', 'C', 'C', 'C', 'H', 'H', 'H', 'H']
#
#                                         coulomb_matrix
# 0    [4.48794386e+02 8.74653979e+01 5.72993516e+01 ...
# ...

# %%
# making dataframe 
df3 = pd.read_csv("output_75000.csv") 
   
# output the dataframe
print(df3)

df3.head(1)
# Out:
#          En     id                               atoms  \
# 0   -0.1000  55004    ['Br', 'Cl', 'N', 'C', 'C', 'H']
# 1    0.2725  61108          ['Br', 'F', 'C', 'H', 'H']
# 2   -0.2433  61169              ['Br', 'Br', 'C', 'C']
# 3   -0.3747  61170                ['I', 'I', 'C', 'C']
# 4    0.1183  61280         ['Br', 'Br', 'F', 'C', 'H']
# 5    0.3869  61330        ['Cl', 'Cl', 'Si', 'H', 'H']
# 6    0.0001  61437             ['Cl', 'Cl', 'Cl', 'N']
# 7    2.5530  61526           ['O', 'O', 'O', 'N', 'N']
# 8    0.0000  61603                ['I', 'I', 'I', 'N']
# 9    0.0240  61621         ['Br', 'Si', 'H', 'H', 'H']
# 10   0.1236  61622         ['Cl', 'Si', 'H', 'H', 'H']
# 11  -2.4297  61681      ['P', 'F', 'F', 'O', 'O', 'H']
# 12   0.1641  61708               ['Cl', 'N', 'N', 'N']
# 13   0.0000  61739                         ['Cl', 'O']
# 14  -0.2360  61744      ['O', 'O', 'N', 'N', 'H', 'H']
# 15   0.5840  61763                ['I', 'N', 'N', 'N']
# ...

# %%
    
# making dataframe 
df4 = pd.read_csv("output_100000.csv") 
   
# output the dataframe
print(df4)

df4.head(1)
# Out:
#          En     id                                              atoms  \
# 0    0.8342  75136  ['O', 'O', 'O', 'N', 'C', 'C', 'C', 'H', 'H', ...
# 1    1.1875  75151  ['S', 'O', 'C', 'C', 'H', 'H', 'H', 'H', 'H', ...
# 2    4.9936  75161      ['O', 'N', 'N', 'N', 'C', 'C', 'H', 'H', 'H']
# 3   -0.3311  75205  ['Br', 'Br', 'C', 'C', 'C', 'C', 'H', 'H', 'H'...
# 4    7.9992  75269  ['O', 'O', 'O', 'C', 'C', 'C', 'H', 'H', 'H', ...
# ..      ...    ...                                                ...
# 200  3.9693  98260          ['Cl', 'F', 'O', 'O', 'C', 'C', 'H', 'H']
# 201  1.4884  98635         ['Cl', 'Cl', 'N', 'N', 'N', 'C', 'C', 'H']
# 202  3.3590  99295  ['S', 'N', 'C', 'C', 'C', 'H', 'H', 'H', 'H', ...
# 203  1.1598  99297      ['F', 'N', 'N', 'C', 'C', 'C', 'H', 'H', 'H']
# 204  1.2927  99484   ['Br', 'Cl', 'Cl', 'N', 'N', 'C', 'C', 'C', 'H']
#
#                                         coulomb_matrix
# 0    [73.51669472 27.92166335 27.99693091 25.368641...
# ...

# %%
    
# making dataframe 
df5 = pd.read_csv("output_125000.csv") 
   
# output the dataframe
print(df5)

df5.head(1)
# Out:
#          En      id                                              atoms  \
# 0    0.9603  100698  ['O', 'N', 'C', 'C', 'C', 'C', 'C', 'H', 'H', ...
# 1    5.9296  100800  ['S', 'O', 'N', 'C', 'C', 'H', 'H', 'H', 'H', ...
# 2   -0.2536  101392  ['O', 'O', 'O', 'C', 'C', 'C', 'H', 'H', 'H', ...
# 3    1.3851  101445           ['O', 'N', 'C', 'C', 'C', 'H', 'H', 'H']
# 4    5.3756  101485         ['Cl', 'Cl', 'N', 'N', 'C', 'C', 'C', 'C']
# ..      ...     ...                                                ...
# 162 -3.9516  123554                ['S', 'O', 'C', 'H', 'H', 'H', 'H']
# 163  3.0138  123582    ['Br', 'Br', 'O', 'C', 'C', 'H', 'H', 'H', 'H']
# 164  5.1736  123975  ['O', 'O', 'O', 'O', 'O', 'O', 'C', 'C', 'H', ...
# 165 -0.0555  124984                               ['S', 'O', 'N', 'C']
# 166 -4.0390  124985                          ['S', 'O', 'N', 'C', 'H']
#
#                                         coulomb_matrix
# 0    [73.51669472 11.74869242 21.35646803 21.355487...
# ...

# %%
    
# making dataframe 
df6 = pd.read_csv("output_150000.csv") 
   
# output the dataframe
print(df6)

df6.head(1)
# Out:
#          En      id                                              atoms  \
# 0    7.4177  126706      ['O', 'O', 'N', 'C', 'C', 'C', 'H', 'H', 'H']
# 1    0.5167  127602           ['F', 'O', 'O', 'C', 'C', 'H', 'H', 'H']
# 2    5.8913  128851      ['S', 'O', 'N', 'C', 'C', 'C', 'H', 'H', 'H']
# 3    1.5635  128857  ['Cl', 'O', 'O', 'C', 'C', 'C', 'C', 'H', 'H',...
# 4    8.2871  130676  ['S', 'N', 'N', 'N', 'N', 'C', 'C', 'C', 'H', ...
# ..      ...     ...                                                ...
# 452  5.9827  148646  ['Br', 'Cl', 'O', 'C', 'C', 'C', 'H', 'H', 'H'...
# 453  6.0583  149399  ['Cl', 'Cl', 'O', 'C', 'C', 'C', 'H', 'H', 'H'...
# 454  5.7821  149428  ['Cl', 'O', 'C', 'C', 'C', 'H', 'H', 'H', 'H',...
# 455  8.1607  149756  ['Cl', 'Cl', 'Cl', 'O', 'C', 'C', 'C', 'H', 'H...
# 456 -2.5923  149953                         ['Cl', 'O', 'N', 'H', 'H']
#
#                                         coulomb_matrix
# 0    [73.51669472 14.44141073 23.756409   18.761439...
# ...

# %%
    
# making dataframe 
df7 = pd.read_csv("output_175000.csv") 
   
# output the dataframe
print(df7)

df7.head(1)
# Out:
#           En      id                                              atoms  \
# 0    -1.0443  150482  ['O', 'N', 'N', 'C', 'C', 'H', 'H', 'H', 'H', ...
# 1     4.7869  150515           ['I', 'O', 'C', 'C', 'C', 'H', 'H', 'H']
# 2     5.0689  150516         ['Cl', 'Cl', 'O', 'C', 'C', 'C', 'H', 'H']
# 3    32.7329  151080  ['C', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', ...
# 4     8.2631  151137  ['Cl', 'O', 'O', 'O', 'C', 'C', 'C', 'H', 'H',...
# ..       ...     ...                                                ...
# 121   2.8350  173032      ['O', 'O', 'O', 'C', 'C', 'H', 'H', 'H', 'H']
# 122   0.0685  173136                ['S', 'P', 'O', 'O', 'H', 'H', 'H']
# 123  13.0172  173730      ['O', 'O', 'N', 'N', 'N', 'N', 'N', 'C', 'H']
# 124   5.9077  174017           ['O', 'O', 'O', 'C', 'C', 'H', 'H', 'H']
# 125   1.4648  174606                ['O', 'N', 'N', 'C', 'H', 'H', 'H']
#
#                                         coulomb_matrix
# ...

# %%
    
# making dataframe 
df8 = pd.read_csv("output_200000.csv") 
   
# output the dataframe
print(df8)

df8.head(1)
# Out:
#          En      id                                              atoms  \
# 0   15.2412  177047                          ['S', 'S', 'P', 'O', 'O']
# 1    3.9060  177062      ['I', 'I', 'I', 'S', 'C', 'C', 'C', 'C', 'H']
# 2    1.5091  177069  ['O', 'O', 'N', 'C', 'C', 'H', 'H', 'H', 'H', ...
# 3   21.1687  177159  ['Cl', 'Cl', 'Cl', 'Cl', 'Cl', 'C', 'C', 'C', ...
# 4    0.0000  177447                                    ['S', 'H', 'H']
# ..      ...     ...                                                ...
# 76 -15.3564  197063  ['S', 'P', 'O', 'O', 'C', 'H', 'H', 'H', 'H', ...
# 77   1.3155  197765                         ['Cl', 'S', 'P', 'F', 'F']
# 78  -0.1303  197839  ['N', 'N', 'N', 'N', 'H', 'H', 'H', 'H', 'H', ...
# 79   2.3983  198669           ['O', 'N', 'N', 'C', 'H', 'H', 'H', 'H']
# 80   1.4648  198676                ['O', 'N', 'N', 'C', 'H', 'H', 'H']
#
#                                        coulomb_matrix
# 0   [388.02344103  85.03002756 120.59296359  43.89...
# ...

# %%
    
# making dataframe 
df9 = pd.read_csv("output_225000.csv") 
   
# output the dataframe
print(df9)

df9.head(1)
# Out:
#         En      id                                              atoms  \
# 0   1.2057  200605    ['Br', 'Br', 'N', 'N', 'C', 'C', 'C', 'H', 'H']
# 1  12.9264  201315  ['S', 'N', 'N', 'N', 'C', 'C', 'C', 'H', 'H', ...
# 2   0.0000  204018                             ['Cl', 'Cl', 'P', 'F']
# 3   2.9449  204804    ['Br', 'Br', 'S', 'C', 'C', 'H', 'H', 'H', 'H']
# 4  12.7362  206611     ['Cl', 'O', 'O', 'N', 'N', 'C', 'H', 'H', 'H']
# 5  17.1821  211207                ['P', 'O', 'O', 'O', 'N', 'H', 'H']
# 6   9.4453  219616  ['Br', 'Br', 'Br', 'O', 'N', 'C', 'C', 'C', 'H...
# 7  12.1476  222465      ['O', 'O', 'C', 'C', 'C', 'H', 'H', 'H', 'H']
# 8   2.4486  222700    ['Cl', 'Cl', 'F', 'F', 'C', 'C', 'C', 'H', 'H']
# 9   3.6703  224991  ['Cl', 'Cl', 'Cl', 'Cl', 'S', 'C', 'C', 'H', 'H']
#
#                                       coulomb_matrix
# 0  [2.62735073e+03 3.39976081e+02 8.56762890e+01 ...
# 1  [388.02344103  41.38947465  29.95583206  41.29...
# ...

# %%
    
# making dataframe 
df10 = pd.read_csv("output_250000.csv") 
   
# output the dataframe
print(df10)

df10.head(1)
# Out:
#          En      id                                              atoms  \
# 0   10.8290  225029  ['N', 'N', 'N', 'N', 'C', 'C', 'H', 'H', 'H', ...
# 1   27.8346  225958  ['Cl', 'Cl', 'Cl', 'Cl', 'Cl', 'O', 'C', 'C', ...
# 2    2.8041  227927  ['O', 'N', 'N', 'N', 'C', 'C', 'C', 'H', 'H', ...
# 3    4.4892  228231  ['S', 'S', 'O', 'O', 'C', 'C', 'H', 'H', 'H', ...
# 4    2.6134  228396  ['Cl', 'F', 'O', 'C', 'C', 'C', 'H', 'H', 'H',...
# 5    0.3592  228397  ['F', 'F', 'O', 'C', 'C', 'C', 'H', 'H', 'H', ...
# 6   13.0328  229071           ['O', 'N', 'N', 'N', 'C', 'C', 'C', 'H']
# 7   -3.0854  230911           ['S', 'S', 'S', 'S', 'S', 'S', 'C', 'C']
# 8    3.8118  231273  ['Cl', 'Cl', 'O', 'C', 'C', 'C', 'H', 'H', 'H'...
# 9   10.5252  234322  ['F', 'F', 'O', 'O', 'O', 'O', 'N', 'C', 'C', ...
# 10   2.5326  235121    ['Br', 'Cl', 'C', 'C', 'C', 'H', 'H', 'H', 'H']
# 11  15.3221  237259  ['Cl', 'Cl', 'Cl', 'N', 'N', 'C', 'C', 'C', 'C...
# ...

# %%
new_df1 = pd.concat([df1, df2], ignore_index=True)
print(new_df1)
last_row = new_df1.iloc[-1:]

#view last row
#print(last_row), axis=0, join= 'outer')
#print(new_df1)
# Out:
#           En     id                                              atoms  \
# 0     7.3580  25020          ['Cl', 'N', 'C', 'C', 'H', 'H', 'H', 'H']
# 1    11.8509  25059  ['Br', 'Br', 'O', 'N', 'N', 'C', 'C', 'C', 'H'...
# 2     1.1785  25128  ['F', 'O', 'O', 'N', 'C', 'C', 'H', 'H', 'H', ...
# 3     4.8583  25188           ['O', 'O', 'C', 'C', 'C', 'H', 'H', 'H']
# 4     0.0000  25242                               ['F', 'F', 'N', 'H']
# ..       ...    ...                                                ...
# 686   0.0000  24823                                    ['O', 'O', 'O']
# 687   0.0000  24841                                         ['I', 'H']
# 688  -0.1416  24845                     ['F', 'F', 'F', 'F', 'N', 'N']
# 689   0.0000  24855                                         ['I', 'I']
# 690   0.4044  24883    ['Cl', 'Cl', 'C', 'C', 'C', 'H', 'H', 'H', 'H']
#
#                                         coulomb_matrix
# 0    [4.48794386e+02 6.75320922e+01 3.86237878e+01 ...
# ...

# %%
new_df2 = pd.concat([new_df1, df3], ignore_index=True)
print(new_df2)
last_row = new_df1.iloc[-1:]

#view last row
#print(last_row), axis=0, join= 'outer')
#print(new_df1)
# Out:
#           En     id                                              atoms  \
# 0     7.3580  25020          ['Cl', 'N', 'C', 'C', 'H', 'H', 'H', 'H']
# 1    11.8509  25059  ['Br', 'Br', 'O', 'N', 'N', 'C', 'C', 'C', 'H'...
# 2     1.1785  25128  ['F', 'O', 'O', 'N', 'C', 'C', 'H', 'H', 'H', ...
# 3     4.8583  25188           ['O', 'O', 'C', 'C', 'C', 'H', 'H', 'H']
# 4     0.0000  25242                               ['F', 'F', 'N', 'H']
# ..       ...    ...                                                ...
# 745   3.2784  71084                  ['Cl', 'Cl', 'Cl', 'F', 'C', 'C']
# 746   0.6658  71568                     ['O', 'C', 'H', 'H', 'H', 'H']
# 747   0.0021  71583                       ['Cl', 'Cl', 'Cl', 'C', 'H']
# 748   1.5701  73894                     ['F', 'F', 'F', 'O', 'C', 'H']
# 749   0.0000  74596                             ['Cl', 'Cl', 'P', 'N']
#
#                                         coulomb_matrix
# 0    [4.48794386e+02 6.75320922e+01 3.86237878e+01 ...
# ...

# %%
new_df3 = pd.concat([new_df2, df4], ignore_index=True)
print(new_df3)
last_row = new_df1.iloc[-1:]

#view last row
#print(last_row), axis=0, join= 'outer')
#print(new_df1)
# Out:
#           En     id                                              atoms  \
# 0     7.3580  25020          ['Cl', 'N', 'C', 'C', 'H', 'H', 'H', 'H']
# 1    11.8509  25059  ['Br', 'Br', 'O', 'N', 'N', 'C', 'C', 'C', 'H'...
# 2     1.1785  25128  ['F', 'O', 'O', 'N', 'C', 'C', 'H', 'H', 'H', ...
# 3     4.8583  25188           ['O', 'O', 'C', 'C', 'C', 'H', 'H', 'H']
# 4     0.0000  25242                               ['F', 'F', 'N', 'H']
# ..       ...    ...                                                ...
# 950   3.9693  98260          ['Cl', 'F', 'O', 'O', 'C', 'C', 'H', 'H']
# 951   1.4884  98635         ['Cl', 'Cl', 'N', 'N', 'N', 'C', 'C', 'H']
# 952   3.3590  99295  ['S', 'N', 'C', 'C', 'C', 'H', 'H', 'H', 'H', ...
# 953   1.1598  99297      ['F', 'N', 'N', 'C', 'C', 'C', 'H', 'H', 'H']
# 954   1.2927  99484   ['Br', 'Cl', 'Cl', 'N', 'N', 'C', 'C', 'C', 'H']
#
#                                         coulomb_matrix
# 0    [4.48794386e+02 6.75320922e+01 3.86237878e+01 ...
# ...

# %%
new_df4 = pd.concat([new_df3, df5], ignore_index=True)
print(new_df4)
last_row = new_df1.iloc[-1:]

#view last row
#print(last_row), axis=0, join= 'outer')
#print(new_df1)
# Out:
#            En      id                                              atoms  \
# 0      7.3580   25020          ['Cl', 'N', 'C', 'C', 'H', 'H', 'H', 'H']
# 1     11.8509   25059  ['Br', 'Br', 'O', 'N', 'N', 'C', 'C', 'C', 'H'...
# 2      1.1785   25128  ['F', 'O', 'O', 'N', 'C', 'C', 'H', 'H', 'H', ...
# 3      4.8583   25188           ['O', 'O', 'C', 'C', 'C', 'H', 'H', 'H']
# 4      0.0000   25242                               ['F', 'F', 'N', 'H']
# ...       ...     ...                                                ...
# 1117  -3.9516  123554                ['S', 'O', 'C', 'H', 'H', 'H', 'H']
# 1118   3.0138  123582    ['Br', 'Br', 'O', 'C', 'C', 'H', 'H', 'H', 'H']
# 1119   5.1736  123975  ['O', 'O', 'O', 'O', 'O', 'O', 'C', 'C', 'H', ...
# 1120  -0.0555  124984                               ['S', 'O', 'N', 'C']
# 1121  -4.0390  124985                          ['S', 'O', 'N', 'C', 'H']
#
#                                          coulomb_matrix
# ...

# %%
new_df5 = pd.concat([new_df4, df6], ignore_index=True)
print(new_df5)
last_row = new_df1.iloc[-1:]

#view last row
#print(last_row), axis=0, join= 'outer')
#print(new_df1)
# Out:
#            En      id                                              atoms  \
# 0      7.3580   25020          ['Cl', 'N', 'C', 'C', 'H', 'H', 'H', 'H']
# 1     11.8509   25059  ['Br', 'Br', 'O', 'N', 'N', 'C', 'C', 'C', 'H'...
# 2      1.1785   25128  ['F', 'O', 'O', 'N', 'C', 'C', 'H', 'H', 'H', ...
# 3      4.8583   25188           ['O', 'O', 'C', 'C', 'C', 'H', 'H', 'H']
# 4      0.0000   25242                               ['F', 'F', 'N', 'H']
# ...       ...     ...                                                ...
# 1574   5.9827  148646  ['Br', 'Cl', 'O', 'C', 'C', 'C', 'H', 'H', 'H'...
# 1575   6.0583  149399  ['Cl', 'Cl', 'O', 'C', 'C', 'C', 'H', 'H', 'H'...
# 1576   5.7821  149428  ['Cl', 'O', 'C', 'C', 'C', 'H', 'H', 'H', 'H',...
# 1577   8.1607  149756  ['Cl', 'Cl', 'Cl', 'O', 'C', 'C', 'C', 'H', 'H...
# 1578  -2.5923  149953                         ['Cl', 'O', 'N', 'H', 'H']
#
#                                          coulomb_matrix
# ...

# %%
new_df6 = pd.concat([new_df5, df7], ignore_index=True)
print(new_df6)
last_row = new_df1.iloc[-1:]

#view last row
#print(last_row), axis=0, join= 'outer')
#print(new_df1)
# Out:
#            En      id                                              atoms  \
# 0      7.3580   25020          ['Cl', 'N', 'C', 'C', 'H', 'H', 'H', 'H']
# 1     11.8509   25059  ['Br', 'Br', 'O', 'N', 'N', 'C', 'C', 'C', 'H'...
# 2      1.1785   25128  ['F', 'O', 'O', 'N', 'C', 'C', 'H', 'H', 'H', ...
# 3      4.8583   25188           ['O', 'O', 'C', 'C', 'C', 'H', 'H', 'H']
# 4      0.0000   25242                               ['F', 'F', 'N', 'H']
# ...       ...     ...                                                ...
# 1700   2.8350  173032      ['O', 'O', 'O', 'C', 'C', 'H', 'H', 'H', 'H']
# 1701   0.0685  173136                ['S', 'P', 'O', 'O', 'H', 'H', 'H']
# 1702  13.0172  173730      ['O', 'O', 'N', 'N', 'N', 'N', 'N', 'C', 'H']
# 1703   5.9077  174017           ['O', 'O', 'O', 'C', 'C', 'H', 'H', 'H']
# 1704   1.4648  174606                ['O', 'N', 'N', 'C', 'H', 'H', 'H']
#
#                                          coulomb_matrix
# ...

# %%
new_df7 = pd.concat([new_df6, df8], ignore_index=True)
print(new_df7)
last_row = new_df1.iloc[-1:]

#view last row
#print(last_row), axis=0, join= 'outer')
#print(new_df1)
# Out:
#            En      id                                              atoms  \
# 0      7.3580   25020          ['Cl', 'N', 'C', 'C', 'H', 'H', 'H', 'H']
# 1     11.8509   25059  ['Br', 'Br', 'O', 'N', 'N', 'C', 'C', 'C', 'H'...
# 2      1.1785   25128  ['F', 'O', 'O', 'N', 'C', 'C', 'H', 'H', 'H', ...
# 3      4.8583   25188           ['O', 'O', 'C', 'C', 'C', 'H', 'H', 'H']
# 4      0.0000   25242                               ['F', 'F', 'N', 'H']
# ...       ...     ...                                                ...
# 1781 -15.3564  197063  ['S', 'P', 'O', 'O', 'C', 'H', 'H', 'H', 'H', ...
# 1782   1.3155  197765                         ['Cl', 'S', 'P', 'F', 'F']
# 1783  -0.1303  197839  ['N', 'N', 'N', 'N', 'H', 'H', 'H', 'H', 'H', ...
# 1784   2.3983  198669           ['O', 'N', 'N', 'C', 'H', 'H', 'H', 'H']
# 1785   1.4648  198676                ['O', 'N', 'N', 'C', 'H', 'H', 'H']
#
#                                          coulomb_matrix
# ...

# %%
new_df8 = pd.concat([new_df7, df9], ignore_index=True)
print(new_df8)
last_row = new_df1.iloc[-1:]

#view last row
#print(last_row), axis=0, join= 'outer')
#print(new_df1)
# Out:
#            En      id                                              atoms  \
# 0      7.3580   25020          ['Cl', 'N', 'C', 'C', 'H', 'H', 'H', 'H']
# 1     11.8509   25059  ['Br', 'Br', 'O', 'N', 'N', 'C', 'C', 'C', 'H'...
# 2      1.1785   25128  ['F', 'O', 'O', 'N', 'C', 'C', 'H', 'H', 'H', ...
# 3      4.8583   25188           ['O', 'O', 'C', 'C', 'C', 'H', 'H', 'H']
# 4      0.0000   25242                               ['F', 'F', 'N', 'H']
# ...       ...     ...                                                ...
# 1791  17.1821  211207                ['P', 'O', 'O', 'O', 'N', 'H', 'H']
# 1792   9.4453  219616  ['Br', 'Br', 'Br', 'O', 'N', 'C', 'C', 'C', 'H...
# 1793  12.1476  222465      ['O', 'O', 'C', 'C', 'C', 'H', 'H', 'H', 'H']
# 1794   2.4486  222700    ['Cl', 'Cl', 'F', 'F', 'C', 'C', 'C', 'H', 'H']
# 1795   3.6703  224991  ['Cl', 'Cl', 'Cl', 'Cl', 'S', 'C', 'C', 'H', 'H']
#
#                                          coulomb_matrix
# ...

# %% [markdown]
# ## This is the final Dataframe !!

# %%
new_df9 = pd.concat([new_df8, df10], ignore_index=True)
print(new_df9)
last_row = new_df1.iloc[-1:]

#view last row
#print(last_row), axis=0, join= 'outer')
#print(new_df1)
# Out:
#            En      id                                              atoms  \
# 0      7.3580   25020          ['Cl', 'N', 'C', 'C', 'H', 'H', 'H', 'H']
# 1     11.8509   25059  ['Br', 'Br', 'O', 'N', 'N', 'C', 'C', 'C', 'H'...
# 2      1.1785   25128  ['F', 'O', 'O', 'N', 'C', 'C', 'H', 'H', 'H', ...
# 3      4.8583   25188           ['O', 'O', 'C', 'C', 'C', 'H', 'H', 'H']
# 4      0.0000   25242                               ['F', 'F', 'N', 'H']
# ...       ...     ...                                                ...
# 1814   4.1919  245975  ['N', 'N', 'N', 'N', 'C', 'C', 'H', 'H', 'H', ...
# 1815   1.1209  247762                  ['Cl', 'Cl', 'Cl', 'S', 'C', 'H']
# 1816   2.5921  248238  ['Cl', 'S', 'O', 'N', 'C', 'C', 'H', 'H', 'H',...
# 1817  14.3931  248852  ['Br', 'Br', 'N', 'N', 'C', 'C', 'C', 'C', 'H'...
# 1818  17.2527  249007  ['Cl', 'Cl', 'Cl', 'N', 'N', 'C', 'C', 'C', 'C...
#
#                                          coulomb_matrix
# ...

# %%
# assume df is your dataframe with a "coulomb_matrix" column containing lists
# use apply() with len() to get the length of each list in the "coulomb_matrix" column
coulomb_matrix_lengths = new_df9["coulomb_matrix"].apply(len)
print(coulomb_matrix_lengths)

# this will create a new Series containing the length of each list in the "coulomb_matrix" column
# you can then use this Series however you want, for example to calculate summary statistics or to plot a histogram
# Out:
# 0        976
# 1       1525
# 2       1209
# 3        779
# 4        194
#         ...
# 1814    1208
# 1815     474
# 1816    1525
# 1817    1525
# 1818    1317
# Name: coulomb_matrix, Length: 1819, dtype: int64
